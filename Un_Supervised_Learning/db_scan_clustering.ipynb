# %% [markdown]
# Uses of Un-supervised Learning:
# - clustering: the model returns the id of the cluster for each feature vector in the dataset.
# - dimensionality reduction: the output of the model is a feature vector that has fewer features than the input x
# - outlier detection: the output is a real number that indicates how x is different from a “typical” example in the dataset.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from sklearn.cluster import DBSCAN 
from sklearn.datasets import make_moons 

X,y = make_moons(n_samples=250,noise=0.1)

# %%
plt.scatter(X[:,0],X[:,1],c=y)
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
# Out:
# Text(0, 0.5, 'Feature 2')

# %%
# feature scaling
from sklearn.preprocessing import StandardScaler 

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
dbscan = DBSCAN(eps=0.3)
dbscan.fit(X_scaled)
# Out:
# DBSCAN(eps=0.3)

# %%
y_classified = dbscan.labels_ 

plt.scatter(X_scaled[:,0],X_scaled[:,1],c=y_classified)
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
# Out:
# Text(0, 0.5, 'Feature 2')

# %% [markdown]
# ### Anomaly Detection

# %%
from sklearn.datasets import make_circles 

X,y = make_circles(n_samples=750, factor=0.3, noise=0.11)
X
# Out:
# array([[ 0.07182661, -0.88670974],
#        [ 0.90771678,  0.38703669],
#        [-0.79094697, -0.93166649],
#        ...,
#        [ 1.14282052, -0.31071416],
#        [-0.05106211, -0.0499651 ],
#        [ 0.27262442,  1.01447595]])

# %%
plt.scatter(X[:,0],X[:,1],c=y)

# %%
dbscan = DBSCAN(eps=0.1,min_samples=5)  # default min_samples=
dbscan.fit_predict(X)
y_pred = dbscan.labels_

# %%
plt.scatter(X[:,0],X[:,1],c=y_pred)
